# %%
# start coding here

# %% [markdown]
# # Add Residual Loads from CSV to Merged Network

# %%
snakemake.input

# %%
import pandas as pd

residual_loads = pd.read_csv(snakemake.input[1], index_col=0, parse_dates=True)
