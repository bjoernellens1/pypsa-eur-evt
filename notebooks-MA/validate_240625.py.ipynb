# %%
import pypsa
# Out:
# Cardinal Optimizer v7.2.9. Build date Jun 20 2025
# Copyright Cardinal Operations 2025. All Rights Reserved

# %%
n = pypsa.Network("../results/128_wAT_entsoe_MA/networks/base_s_128_elec_.nc")
# Out:
# INFO:pypsa.io:Imported network base_s_128_elec_.nc has buses, carriers, generators, lines, links, loads, storage_units, stores

# %%
n.loads_t.p_set
# Out:
# Load                      AL0 0     AT0 0     AT0 1    AT0 10    AT0 11  \
# snapshot
# 2013-01-01 00:00:00  745.586198  0.000245  0.000245  0.000245  0.000245
# 2013-01-01 06:00:00  800.948275  0.000249  0.000249  0.000249  0.000249
# 2013-01-01 12:00:00  876.620689  0.000245  0.000245  0.000245  0.000245
# 2013-01-01 18:00:00  912.327588  0.000247  0.000247  0.000247  0.000247
# 2013-01-02 00:00:00  697.103451  0.000000  0.000000  0.000000  0.000000
# ...                         ...       ...       ...       ...       ...
# 2013-12-30 18:00:00  943.120691  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 00:00:00  682.689651  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 06:00:00  882.844827  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 12:00:00  962.120691  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 18:00:00  896.275857  0.000052  0.000052  0.000052  0.000052
#
# Load                   AT0 12    AT0 13    AT0 14    AT0 15    AT0 16  ...  \
# snapshot                                                               ...
# 2013-01-01 00:00:00  0.000245  0.000245  0.000245  0.000245  0.000245  ...
# 2013-01-01 06:00:00  0.000249  0.000249  0.000249  0.000249  0.000249  ...
# 2013-01-01 12:00:00  0.000245  0.000245  0.000245  0.000245  0.000245  ...
# 2013-01-01 18:00:00  0.000247  0.000247  0.000247  0.000247  0.000247  ...
# 2013-01-02 00:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2013-12-30 18:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 00:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 06:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 12:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 18:00:00  0.000052  0.000052  0.000052  0.000052  0.000052  ...
#
# Load                       PT0 0        RO0 0        RS0 0        SE1 0  \
# snapshot
# 2013-01-01 00:00:00  4196.166674  5441.333328  4913.333331  6046.938800
# 2013-01-01 06:00:00  3941.666670  5149.500014  4915.166670  6611.448432
# 2013-01-01 12:00:00  4570.500000  5753.499980  5481.833330  7432.534156
# 2013-01-01 18:00:00  5491.666670  5708.333333  5662.833330  6932.767361
# 2013-01-02 00:00:00  4125.500004  5104.166663  4641.166660  6404.539055
# ...                          ...          ...          ...          ...
# 2013-12-30 18:00:00  6829.166670  5807.666670  5954.499997  7097.477638
# 2013-12-31 00:00:00  4535.000003  4934.666668  4599.333333  6139.509079
# 2013-12-31 06:00:00  5348.500006  5843.499997  5613.333335  7017.799567
# 2013-12-31 12:00:00  6093.333338  6470.666665  6166.666668  7627.185376
# 2013-12-31 18:00:00  5877.000000  6010.666678  5635.500000  6677.952506
#
# Load                        SE1 1        SI0 0        SK0 0        UA0 0  \
# snapshot
# 2013-01-01 00:00:00   8258.727867  1106.333333  2619.666672  3758.628777
# 2013-01-01 06:00:00   9029.718239  1072.666669  2718.666669  4056.550919
# 2013-01-01 12:00:00  10151.132507  1154.000000  2974.500004  4440.387405
# 2013-01-01 18:00:00   9468.565985  1153.333331  2971.499992  4128.699070
# 2013-01-02 00:00:00   8747.127611  1072.166663  2687.999992  3850.265228
# ...                           ...          ...          ...          ...
# 2013-12-30 18:00:00   9693.522359  1241.833337  2972.666667  4664.958911
# 2013-12-31 00:00:00   8385.157584  1064.666665  2492.833337  4466.095371
# 2013-12-31 06:00:00   9584.700436  1326.999996  3016.333328  5299.572444
# 2013-12-31 12:00:00  10416.981302  1382.166665  3145.499995  5521.531704
# 2013-12-31 18:00:00   9120.547488  1141.333336  2862.666655  4671.178579
#
# Load                       UA0 1        UA0 2
# snapshot
# 2013-01-01 00:00:00  6017.315041  5399.485420
# 2013-01-01 06:00:00  6494.268586  5827.467625
# 2013-01-01 12:00:00  7108.765324  6378.870703
# 2013-01-01 18:00:00  6609.773001  5931.112574
# 2013-01-02 00:00:00  6164.018921  5531.126417
# ...                          ...          ...
# 2013-12-30 18:00:00  7468.289382  6701.480526
# 2013-12-31 00:00:00  7149.922063  6415.801690
# 2013-12-31 06:00:00  8484.263510  7613.139210
# 2013-12-31 12:00:00  8839.605539  7931.996376
# 2013-12-31 18:00:00  7478.246672  6710.415452
#
# [1460 rows x 152 columns]

# %%
n.generators
# Out:
#                 bus control type     p_nom  p_nom_mod  p_nom_extendable  \
# Generator
# AT0 0 CCGT    AT0 0   Slack         60.000        0.0              True
# AT0 10 CCGT  AT0 10      PV         41.000        0.0              True
# AT0 17 CCGT  AT0 17      PV       1190.000        0.0              True
# AT0 29 CCGT  AT0 29      PV        311.000        0.0              True
# AT0 32 CCGT  AT0 32      PV       1679.200        0.0              True
# ...             ...     ...  ...       ...        ...               ...
# RS0 0 ror     RS0 0      PV       1708.400        0.0             False
# SE1 0 ror     SE1 0      PV       1118.000        0.0             False
# SE1 1 ror     SE1 1      PV        161.000        0.0             False
# SI0 0 ror     SI0 0      PV        504.415        0.0             False
# SK0 0 ror     SK0 0      PV       1217.690        0.0             False
#
#              p_nom_min  p_nom_max  p_min_pu  p_max_pu  ...  min_up_time  \
# Generator                                              ...
# AT0 0 CCGT        60.0        inf       0.0       1.0  ...            0
# AT0 10 CCGT       41.0        inf       0.0       1.0  ...            0
# AT0 17 CCGT     1190.0        inf       0.0       1.0  ...            0
# AT0 29 CCGT      311.0        inf       0.0       1.0  ...            0
# AT0 32 CCGT     1679.2        inf       0.0       1.0  ...            0
# ...                ...        ...       ...       ...  ...          ...
# RS0 0 ror          0.0        inf       0.0       1.0  ...            0
# SE1 0 ror          0.0        inf       0.0       1.0  ...            0
# SE1 1 ror          0.0        inf       0.0       1.0  ...            0
# SI0 0 ror          0.0        inf       0.0       1.0  ...            0
# SK0 0 ror          0.0        inf       0.0       1.0  ...            0
#
#              min_down_time  up_time_before  down_time_before  ramp_limit_up  \
# Generator
# AT0 0 CCGT               0               1                 0            NaN
# AT0 10 CCGT              0               1                 0            NaN
# AT0 17 CCGT              0               1                 0            NaN
# AT0 29 CCGT              0               1                 0            NaN
# AT0 32 CCGT              0               1                 0            NaN
# ...                    ...             ...               ...            ...
# RS0 0 ror                0               1                 0            NaN
# SE1 0 ror                0               1                 0            NaN
# SE1 1 ror                0               1                 0            NaN
# SI0 0 ror                0               1                 0            NaN
# SK0 0 ror                0               1                 0            NaN
#
#             ramp_limit_down  ramp_limit_start_up  ramp_limit_shut_down  \
# Generator
# AT0 0 CCGT              NaN                  1.0                   1.0
# AT0 10 CCGT             NaN                  1.0                   1.0
# AT0 17 CCGT             NaN                  1.0                   1.0
# AT0 29 CCGT             NaN                  1.0                   1.0
# AT0 32 CCGT             NaN                  1.0                   1.0
# ...                     ...                  ...                   ...
# RS0 0 ror               NaN                  1.0                   1.0
# SE1 0 ror               NaN                  1.0                   1.0
# SE1 1 ror               NaN                  1.0                   1.0
# SI0 0 ror               NaN                  1.0                   1.0
# SK0 0 ror               NaN                  1.0                   1.0
#
#                weight    p_nom_opt
# Generator
# AT0 0 CCGT      1.000    60.000026
# AT0 10 CCGT     1.000    41.000060
# AT0 17 CCGT     1.000  1190.000232
# AT0 29 CCGT     1.000   311.000113
# AT0 32 CCGT     1.000  1679.200329
# ...               ...          ...
# RS0 0 ror    1708.400  1708.400000
# SE1 0 ror    1118.000  1118.000000
# SE1 1 ror     161.000   161.000000
# SI0 0 ror     504.415   504.415000
# SK0 0 ror    1217.690  1217.690000
#
# [854 rows x 37 columns]

# %%
n_elec = pypsa.Network("../resources/networks/base_s_128_elec.nc")
# Out:
# INFO:pypsa.io:Imported network base_s_128_elec.nc has buses, carriers, generators, lines, links, loads, storage_units, stores

# %%
n_elec.loads_t.p_set
# Out:
# Load                      AL0 0       AT0 0       AT0 1      AT0 10  \
# snapshot
# 2013-01-01 00:00:00  845.172409   92.213898  210.686905  263.460617
# 2013-01-01 01:00:00  794.068954   88.395752  201.963356  252.551956
# 2013-01-01 02:00:00  740.999992   83.666466  191.158051  239.040092
# 2013-01-01 03:00:00  707.586197   83.362747  190.464134  238.172363
# 2013-01-01 04:00:00  691.862053   84.418526  192.876328  241.188774
# ...                         ...         ...         ...         ...
# 2013-12-31 19:00:00  959.172409  107.341835  245.250664  306.682037
# 2013-12-31 20:00:00  908.068977  102.077423  233.222740  291.641312
# 2013-12-31 21:00:00  853.034477  106.387299  243.069771  303.954872
# 2013-12-31 22:00:00  835.344818  101.036118  230.843590  288.666222
# 2013-12-31 23:00:00  811.758614   97.536156  222.847000  278.666618
#
# Load                     AT0 11      AT0 12      AT0 13      AT0 14  \
# snapshot
# 2013-01-01 00:00:00  117.370552  126.497513  117.881744   96.899239
# 2013-01-01 01:00:00  112.510796  121.259850  113.000824   92.887100
# 2013-01-01 02:00:00  106.491318  114.772285  106.955132   87.917519
# 2013-01-01 03:00:00  106.104744  114.355659  106.566872   87.598373
# 2013-01-01 04:00:00  107.448540  115.803947  107.916527   88.707794
# ...                         ...         ...         ...         ...
# 2013-12-31 19:00:00  136.625504  147.249771  137.220558  112.795822
# 2013-12-31 20:00:00  129.924927  140.028145  130.490807  107.263939
# 2013-12-31 21:00:00  135.410568  145.940353  136.000336  111.792793
# 2013-12-31 22:00:00  128.599541  138.599693  129.159645  106.169716
# 2013-12-31 23:00:00  124.144760  133.798500  124.685455  102.491920
#
# Load                    AT0 15      AT0 16  ...        PT0 0        RO0 0  \
# snapshot                                    ...
# 2013-01-01 00:00:00  42.389999  201.089966  ...  4749.999992  5778.999985
# 2013-01-01 01:00:00  40.634827  192.763779  ...  4557.000000  5560.000046
# 2013-01-01 02:00:00  38.460808  182.450668  ...  4261.999985  5402.999985
# 2013-01-01 03:00:00  38.321198  181.788353  ...  4002.000023  5348.000000
# 2013-01-01 04:00:00  38.806526  184.090668  ...  3852.000031  5324.999969
# ...                        ...         ...  ...          ...          ...
# 2013-12-31 19:00:00  49.344193  234.079315  ...  6483.999992  6304.000031
# 2013-12-31 20:00:00  46.924187  222.599274  ...  5869.000000  6093.999992
# 2013-12-31 21:00:00  48.905396  231.997765  ...  5543.000008  5894.000023
# 2013-12-31 22:00:00  46.445503  220.328499  ...  5391.000008  5696.999992
# 2013-12-31 23:00:00  44.836594  212.696159  ...  5138.999977  5458.000015
#
# Load                       RS0 0        SE1 0        SE1 1        SI0 0  \
# snapshot
# 2013-01-01 00:00:00  5579.999985  6175.579109  8434.420906  1161.000008
# 2013-01-01 01:00:00  5287.999992  6062.719421  8280.280579  1110.000000
# 2013-01-01 02:00:00  4962.999977  5967.190269  8149.809731  1089.999992
# 2013-01-01 03:00:00  4673.000015  5900.404411  8058.595596  1074.000000
# 2013-01-01 04:00:00  4515.000008  6014.109451  8213.890526  1082.999992
# ...                          ...          ...          ...          ...
# 2013-12-31 19:00:00  6025.999985  6913.605164  9442.394836  1225.000000
# 2013-12-31 20:00:00  5599.000000  6716.629120  9173.370857  1125.000015
# 2013-12-31 21:00:00  5323.999992  6532.756653  8922.243332  1066.000000
# 2013-12-31 22:00:00  5215.000000  6388.194824  8724.805145  1015.000000
# 2013-12-31 23:00:00  5257.000023  6271.953621  8566.046387  1082.999992
#
# Load                       SK0 0        UA0 0        UA0 1        UA0 2
# snapshot
# 2013-01-01 00:00:00  2785.000000  3936.552765  6302.159515  5655.083420
# 2013-01-01 01:00:00  2658.000008  3820.618149  6116.555893  5488.536697
# 2013-01-01 02:00:00  2571.000031  3785.290421  6059.998573  5437.786392
# 2013-01-01 03:00:00  2555.000000  3726.327972  5965.603569  5353.083450
# 2013-01-01 04:00:00  2558.999985  3690.751442  5908.647949  5301.975754
# ...                          ...          ...          ...          ...
# 2013-12-31 19:00:00  2957.999992  4939.163368  7907.272530  7095.390953
# 2013-12-31 20:00:00  2851.000000  4738.143684  7585.453308  6806.614647
# 2013-12-31 21:00:00  2820.999977  4537.124008  7263.634201  6517.838356
# 2013-12-31 22:00:00  2774.999985  4390.837372  7029.439026  6307.689247
# 2013-12-31 23:00:00  2717.999992  4228.628403  6769.753258  6074.666817
#
# [8760 rows x 128 columns]

# %%
n.plot(
    line_widths=0.5,
    link_widths=0.5,
    bus_sizes=0.0025,
    boundaries=[7, 18, 46, 49.5] # Focused boundaries for Austria
)
# Out:
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# (<matplotlib.collections.PatchCollection at 0x7ad50480e990>,
#  <matplotlib.collections.LineCollection at 0x7ad50418b170>,
#  <matplotlib.collections.LineCollection at 0x7ad502350230>)

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
network = n.copy()

# %%
fig, ax = plt.subplots(
    1, 1, subplot_kw={"projection": ccrs.EqualEarth()}, figsize=(8, 8)
)

load_distribution = (
    network.loads_t.p_set.loc[network.snapshots[0]].groupby(network.loads.bus).sum()
)
network.plot(bus_sizes=1e-5 * load_distribution, ax=ax, title="Load distribution");
# Out:
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
fig, ax = plt.subplots(
    1, 1, subplot_kw={"projection": ccrs.EqualEarth()}, figsize=(8, 8)
)

load_distribution = (
    network.loads_t.p_set.loc[network.snapshots[0]].groupby(network.loads.bus).sum()
)
network.plot(bus_sizes=1e-5 * load_distribution, ax=ax, title="Load distribution");
# Out:
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n.loads_t.p_set
# Out:
# Load                      AL0 0     AT0 0     AT0 1    AT0 10    AT0 11  \
# snapshot
# 2013-01-01 00:00:00  745.586198  0.000245  0.000245  0.000245  0.000245
# 2013-01-01 06:00:00  800.948275  0.000249  0.000249  0.000249  0.000249
# 2013-01-01 12:00:00  876.620689  0.000245  0.000245  0.000245  0.000245
# 2013-01-01 18:00:00  912.327588  0.000247  0.000247  0.000247  0.000247
# 2013-01-02 00:00:00  697.103451  0.000000  0.000000  0.000000  0.000000
# ...                         ...       ...       ...       ...       ...
# 2013-12-30 18:00:00  943.120691  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 00:00:00  682.689651  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 06:00:00  882.844827  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 12:00:00  962.120691  0.000000  0.000000  0.000000  0.000000
# 2013-12-31 18:00:00  896.275857  0.000052  0.000052  0.000052  0.000052
#
# Load                   AT0 12    AT0 13    AT0 14    AT0 15    AT0 16  ...  \
# snapshot                                                               ...
# 2013-01-01 00:00:00  0.000245  0.000245  0.000245  0.000245  0.000245  ...
# 2013-01-01 06:00:00  0.000249  0.000249  0.000249  0.000249  0.000249  ...
# 2013-01-01 12:00:00  0.000245  0.000245  0.000245  0.000245  0.000245  ...
# 2013-01-01 18:00:00  0.000247  0.000247  0.000247  0.000247  0.000247  ...
# 2013-01-02 00:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2013-12-30 18:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 00:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 06:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 12:00:00  0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 2013-12-31 18:00:00  0.000052  0.000052  0.000052  0.000052  0.000052  ...
#
# Load                       PT0 0        RO0 0        RS0 0        SE1 0  \
# snapshot
# 2013-01-01 00:00:00  4196.166674  5441.333328  4913.333331  6046.938800
# 2013-01-01 06:00:00  3941.666670  5149.500014  4915.166670  6611.448432
# 2013-01-01 12:00:00  4570.500000  5753.499980  5481.833330  7432.534156
# 2013-01-01 18:00:00  5491.666670  5708.333333  5662.833330  6932.767361
# 2013-01-02 00:00:00  4125.500004  5104.166663  4641.166660  6404.539055
# ...                          ...          ...          ...          ...
# 2013-12-30 18:00:00  6829.166670  5807.666670  5954.499997  7097.477638
# 2013-12-31 00:00:00  4535.000003  4934.666668  4599.333333  6139.509079
# 2013-12-31 06:00:00  5348.500006  5843.499997  5613.333335  7017.799567
# 2013-12-31 12:00:00  6093.333338  6470.666665  6166.666668  7627.185376
# 2013-12-31 18:00:00  5877.000000  6010.666678  5635.500000  6677.952506
#
# Load                        SE1 1        SI0 0        SK0 0        UA0 0  \
# snapshot
# 2013-01-01 00:00:00   8258.727867  1106.333333  2619.666672  3758.628777
# 2013-01-01 06:00:00   9029.718239  1072.666669  2718.666669  4056.550919
# 2013-01-01 12:00:00  10151.132507  1154.000000  2974.500004  4440.387405
# 2013-01-01 18:00:00   9468.565985  1153.333331  2971.499992  4128.699070
# 2013-01-02 00:00:00   8747.127611  1072.166663  2687.999992  3850.265228
# ...                           ...          ...          ...          ...
# 2013-12-30 18:00:00   9693.522359  1241.833337  2972.666667  4664.958911
# 2013-12-31 00:00:00   8385.157584  1064.666665  2492.833337  4466.095371
# 2013-12-31 06:00:00   9584.700436  1326.999996  3016.333328  5299.572444
# 2013-12-31 12:00:00  10416.981302  1382.166665  3145.499995  5521.531704
# 2013-12-31 18:00:00   9120.547488  1141.333336  2862.666655  4671.178579
#
# Load                       UA0 1        UA0 2
# snapshot
# 2013-01-01 00:00:00  6017.315041  5399.485420
# 2013-01-01 06:00:00  6494.268586  5827.467625
# 2013-01-01 12:00:00  7108.765324  6378.870703
# 2013-01-01 18:00:00  6609.773001  5931.112574
# 2013-01-02 00:00:00  6164.018921  5531.126417
# ...                          ...          ...
# 2013-12-30 18:00:00  7468.289382  6701.480526
# 2013-12-31 00:00:00  7149.922063  6415.801690
# 2013-12-31 06:00:00  8484.263510  7613.139210
# 2013-12-31 12:00:00  8839.605539  7931.996376
# 2013-12-31 18:00:00  7478.246672  6710.415452
#
# [1460 rows x 152 columns]

# %%
techs = ["CCGT", "coal", "nuclear", "offwind-ac", "onwind", "solar", "ror", "biomass", "oil"]

n_graphs = len(techs)
n_cols = 3
if n_graphs % n_cols == 0:
    n_rows = n_graphs // n_cols
else:
    n_rows = n_graphs // n_cols + 1


fig, axes = plt.subplots(
    nrows=n_rows, ncols=n_cols, subplot_kw={"projection": ccrs.EqualEarth()}
)
size = 6
fig.set_size_inches(size * n_cols, size * n_rows)

for i, tech in enumerate(techs):
    i_row = i // n_cols
    i_col = i % n_cols

    ax = axes[i_row, i_col]
    gens = network.generators[network.generators.carrier == tech]
    gen_distribution = (
        gens.groupby("bus").sum()["p_nom"].reindex(network.buses.index, fill_value=0.0)
    )
    network.plot(ax=ax, bus_sizes=2e-5 * gen_distribution)
    ax.set_title(tech)
fig.tight_layout()
# Out:
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
p_by_carrier = network.generators_t.p.groupby(network.generators.carrier, axis=1).sum()
p_by_carrier.drop(
    (p_by_carrier.max()[p_by_carrier.max() < 1700.0]).index, axis=1, inplace=True
)
p_by_carrier.columns
# Out:
# /tmp/ipykernel_3843642/901685434.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   p_by_carrier = network.generators_t.p.groupby(network.generators.carrier, axis=1).sum()
# Index(['CCGT', 'biomass', 'coal', 'lignite', 'nuclear', 'offwind-ac',
#        'offwind-dc', 'offwind-float', 'onwind', 'ror', 'solar', 'solar-hsat'],
#       dtype='object', name='carrier')

# %%
colors = {
    "lignite": "brown",
    "coal": "k",
    "nuclear": "r",
    "ror": "green",
    "onwind": "blue",
    "solar": "yellow",
    "offwind-ac": "cyan",
    "Waste": "orange",
    "CCGT": "orange",
}
# reorder
cols = [
    "nuclear",
    "ror",
    "lignite",
    "coal",
    "CCGT",
    "offwind-ac",
    "onwind",
    "solar",
]
p_by_carrier = p_by_carrier[cols]

# %%
c = [colors[col] for col in p_by_carrier.columns]

fig, ax = plt.subplots(figsize=(12, 6))
(p_by_carrier / 1e3).plot(kind="area", ax=ax, linewidth=4, color=c, alpha=0.7)
ax.legend(ncol=4, loc="upper left")
ax.set_ylabel("GW")
ax.set_xlabel("")
fig.tight_layout()

# %%
network.storage_units_t.p
# Out:
# StorageUnit          AT0 14 PHS  AT0 16 PHS  AT0 18 PHS   AT0 35 PHS  \
# snapshot
# 2013-01-01 00:00:00    0.000038    0.000108    0.000053  -208.345143
# 2013-01-01 06:00:00  -49.999575 -721.640523   -0.000347 -1040.999570
# 2013-01-01 12:00:00    0.000139   -0.001093   -0.003221 -1040.998817
# 2013-01-01 18:00:00    0.000257    0.000148   -0.000060    -0.000249
# 2013-01-02 00:00:00    0.000062   -0.000775   -0.000813 -1040.993547
# ...                         ...         ...         ...          ...
# 2013-12-30 18:00:00    0.001331   -0.000049   -0.000121    -0.000373
# 2013-12-31 00:00:00    0.000503   -0.000651   -0.000853 -1040.997906
# 2013-12-31 06:00:00    0.000295   -0.001738   -0.152953 -1040.998831
# 2013-12-31 12:00:00    0.000485   -0.000774   -0.001187 -1040.998859
# 2013-12-31 18:00:00    0.000310   -0.000426   -0.000373    -0.001355
#
# StorageUnit          AT0 37 PHS   AT0 38 PHS  AT0 4 PHS   AT0 8 PHS  \
# snapshot
# 2013-01-01 00:00:00   -0.000496     0.000135  -0.000055    0.000132
# 2013-01-01 06:00:00 -478.999601    -0.000909  -0.002803 -590.984736
# 2013-01-01 12:00:00   -0.006592 -1332.797094  -0.003074   -0.001843
# 2013-01-01 18:00:00   -0.000064    -0.000152  -0.000040    0.000019
# 2013-01-02 00:00:00   -0.001084    -0.003205  -0.000824   -0.000841
# ...                         ...          ...        ...         ...
# 2013-12-30 18:00:00   -0.000141    -0.000333  -0.000115   -0.000076
# 2013-12-31 00:00:00   -0.001073    -0.004436  -0.000846   -0.000827
# 2013-12-31 06:00:00   -0.038932 -1332.798115  -0.102345   -0.005607
# 2013-12-31 12:00:00   -0.001406 -1135.557260  -0.001329   -0.001109
# 2013-12-31 18:00:00   -0.000460    -0.000974  -0.000379   -0.000372
#
# StorageUnit          BA0 0 PHS   BE0 0 PHS  ...  PL0 1 hydro  PT0 0 hydro  \
# snapshot                                    ...
# 2013-01-01 00:00:00  -0.000081 -950.973465  ...     0.000071  1159.393385
# 2013-01-01 06:00:00  -0.669245 -147.916071  ...     0.000082     0.000765
# 2013-01-01 12:00:00   0.000447    0.000608  ...    33.896652     0.000767
# 2013-01-01 18:00:00   0.000214    0.000113  ...    33.896171  1159.399696
# 2013-01-02 00:00:00   0.000131   -0.000033  ...     0.001673     0.001929
# ...                        ...         ...  ...          ...          ...
# 2013-12-30 18:00:00   0.000318    0.000208  ...    33.895962  1159.399694
# 2013-12-31 00:00:00   0.000363    0.000204  ...     0.002200     0.001740
# 2013-12-31 06:00:00   0.000339    0.000327  ...    33.896864     0.000767
# 2013-12-31 12:00:00   0.000628    0.000515  ...    33.896628     0.000886
# 2013-12-31 18:00:00   0.000904    0.001414  ...    33.896487  1159.399606
#
# StorageUnit          RO0 0 hydro  RS0 0 hydro  SE1 0 hydro  SE1 1 hydro  \
# snapshot
# 2013-01-01 00:00:00     0.000451    41.506993     0.000249     0.000187
# 2013-01-01 06:00:00     0.000247    45.337849     0.000600     0.000297
# 2013-01-01 12:00:00     0.010069    92.279341  5725.784025     1.925092
# 2013-01-01 18:00:00  3836.603956    82.995900  4799.503108     1.900944
# 2013-01-02 00:00:00     0.013445    73.989058   497.631447     1.751219
# ...                          ...          ...          ...          ...
# 2013-12-30 18:00:00  4449.592252   181.272396  2667.451758     1.761689
# 2013-12-31 00:00:00     0.007228   181.727806     0.003132     0.001440
# 2013-12-31 06:00:00     0.004524   182.171637  4717.312825     1.736638
# 2013-12-31 12:00:00  3984.005579   181.455246  2766.757549     1.895412
# 2013-12-31 18:00:00  3739.976555   181.554594  1806.708842     1.737665
#
# StorageUnit          SI0 0 hydro  SK0 0 hydro  UA0 1 hydro  UA0 2 hydro
# snapshot
# 2013-01-01 00:00:00     0.000397     0.000172     0.000273     0.000231
# 2013-01-01 06:00:00     0.000203     0.000120     0.000198     0.000167
# 2013-01-01 12:00:00   576.186720     0.003999   511.522557     0.419374
# 2013-01-01 18:00:00   576.176082   282.397694   458.988456     3.030680
# 2013-01-02 00:00:00   576.188315     0.002803   413.325462     3.090261
# ...                          ...          ...          ...          ...
# 2013-12-30 18:00:00   576.158661   282.397947   668.392660     3.155981
# 2013-12-31 00:00:00   576.188446     0.002262     0.014599     0.013267
# 2013-12-31 06:00:00     0.318467     0.002803   689.264583     2.884397
# 2013-12-31 12:00:00   576.187862   282.391450   700.679929  1648.220539
# 2013-12-31 18:00:00   576.186699   282.395948   636.263625   205.248728
#
# [1460 rows x 122 columns]

# %%
network.storage_units_t.p.sum(axis=1)
# Out:
# snapshot
# 2013-01-01 00:00:00   -13948.523064
# 2013-01-01 06:00:00   -41440.065548
# 2013-01-01 12:00:00     2285.638568
# 2013-01-01 18:00:00    46673.707323
# 2013-01-02 00:00:00    17257.435700
#                            ...
# 2013-12-30 18:00:00    51792.281876
# 2013-12-31 00:00:00     4165.071436
# 2013-12-31 06:00:00    -5266.437996
# 2013-12-31 12:00:00    18456.438756
# 2013-12-31 18:00:00    34931.640509
# Length: 1460, dtype: float64

# %%
p_storage.plot()
# Out:
# <Axes: xlabel='snapshot'>

# %%
fig, ax = plt.subplots(figsize=(12, 6))

p_storage = network.storage_units_t.p.sum(axis=1)
state_of_charge = network.storage_units_t.state_of_charge.sum(axis=1)
p_storage.plot(label="Pumped hydro dispatch", ax=ax, linewidth=3)
state_of_charge.plot(label="State of charge", ax=ax, linewidth=3)

ax.legend()
ax.grid()
ax.set_ylabel("MWh")
ax.set_xlabel("")
fig.tight_layout()

# %% [markdown]
# # Flow Plot

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import pandas as pd

import pypsa

plt.rc("figure", figsize=(10, 8))

# %%
n = network

# %%
gen = n.generators.assign(g=n.generators_t.p.mean()).groupby(["bus", "carrier"]).g.sum()

# %%
# links are not displayed for prettier output ('link_widths=0')
n.plot(
    bus_sizes=gen / 5e4,
    margin=0.5,
    line_widths=0.1,
    flow="mean",
    link_widths=0,
)
plt.show()
# Out:
# /home/bjoern_local/miniforge3/envs/pypsa-eur/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n.statistics.supply(comps=["Generator"]).droplevel(0).div(1e3).plot.bar(
    title="Generator in GWh"
)
# Out:
# <Axes: title={'center': 'Generator in GWh'}, xlabel='carrier'>

# %%
fig, ax = plt.subplots()
n.statistics.supply(comps=["Generator"], aggregate_time=False).droplevel(0).iloc[
    :, :4
].div(1e3).T.plot.area(
    title="Generation in GW",
    ax=ax,
    legend=False,
    linewidth=0,
)
ax.legend(bbox_to_anchor=(1, 0), loc="lower left", title=None, ncol=1)
